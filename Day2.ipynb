# %% [markdown]
# <a href="https://colab.research.google.com/github/mapzacer-11/Machine-Learning-Journey/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Identifiers and Keywords
name_2='Adnan'
print(name_2)
# Out:
# Adnan

# %%
#user Inputs
input('Apna naam bol')
# Out:
# Apna naam bolAdnan
# 'Adnan'

# %%
#type conversion
# implicit vs Explicit
print(5+5.6)
print(type(5),type(5.6))
# Out:
# 10.6
# <class 'int'> <class 'float'>

# %%
#first program with Type conversion
#take input from user and store them in variable
firstnum = input('Enter Your First Number')
secondnum = input('Enter Your Second Number')
#print(type(firstnum),type(secondnum))
#add the 2 variables
result = int(firstnum) +int(secondnum)
#print the result
print(result)
print(type(firstnum))
# Out:
# Enter Your First Number22
# Enter Your Second Number45
# 67
# <class 'str'>

# %%
#literals
a=0b1010
print(a)
b=100
print(b)
c=0o310
print(c)
d=0x21c
print(d)
#Float Literal
float_1=10.5
float_2=1.5e2
print(float_1,float_2)

#complex literal
x=3.14j
print(x,x.imag,x.real)
# Out:
# 10
# 100
# 200
# 540
# 10.5 150.0
# 3.14j 3.14 0.0

# %%
#python treats boolean as number
a=True+4
b=False+10
print("a:",a)
print("b:",b)
# Out:
# a: 5
# b: 10
