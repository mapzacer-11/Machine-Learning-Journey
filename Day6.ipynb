# %% [markdown]
# <a href="https://colab.research.google.com/github/mapzacer-11/Machine-Learning-Journey/blob/main/Day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#creating Strings

s = 'hello'
s = "hello"

#multipe strings
s = '''hello'''
s = """hello"""
print(s)
# Out:
# hello

# %%
#diff diff scenarios
"it's big"
# Out:
# "it's big"

# %%
#Indexing
#positive indexing(left to right)
s = 'hello bros'
print(s[7])
# Out:
# r

# %%
#negative indexing(right to left)
s='hello universe'
print(s[-10])
# Out:
# o

# %%
#slicing
a='alferado hehe'
print(a[0:8])
#we
# Out:
# alferado

# %%
#Editing and Deleting in strings
s='hello world'
s=[0]='H'
# Python strings are immutable
# Out:
#   File "/tmp/ipython-input-3079426723.py", line 3
#     s=[0]='H'
#        ^
# SyntaxError: cannot assign to literal

# %%
s = 'hello universe'
del s[4]
print(s)
#full string can be deleted
#part of string can't
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1199761222.py in <cell line: 0>()
#       1 s = 'hello universe'
# ----> 2 del s[4]
#       3 print(s)
#
# TypeError: 'str' object doesn't support item deletion

# %%
#Operations On Strings

#Arithmetic operators
print('Accha'+'aisahai')
# Out:
# Acchaaisahai

# %%
print("I dont do any mistake after this"*30)
# Out:
# I dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after thisI dont do any mistake after this

# %%
#Relational Operators
'Addu'=='Addu'
# Out:
# True

# %%
'Addu'=='addu'
#Because of ASCII value
# Out:
# False

# %%
'karnataka'>'mumbai'
# Out:
# False

# %%
'karnataka'>'goa'
# Because its lexiographically
# Out:
# True

# %%
'hello' and 'india'
# Out:
# 'india'

# %%
'hello'or'baengal'
# Out:
# 'hello'

# %%
not 'hello'
# Out:
# False

# %%
not ''
# Out:
# True

# %%
#loops in strings
for i in 'karnataka': # it print based on the no of strings
  print('MAP')
# Out:
# MAP
# MAP
# MAP
# MAP
# MAP
# MAP
# MAP
# MAP
# MAP

# %%
#membership operators
'A' in 'adnan'
# Out:
# False
