# %% [markdown]
# <a href="https://colab.research.google.com/github/mapzacer-11/Machine-Learning-Journey/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World')
# Out:
# Hello World

# %%
print('Adnan is Here')
# Out:
# Adnan is Here

# %%
print(26,0.8,True)
# Out:
# 26 0.8 True

# %%
print(26,0.8,True,sep='/')
# Out:
# 26/0.8/True

# %%
print('hello')
print('world')
# Out:
# hello
# world

# %%
print('hello',end='-')
print('world')
# Out:
# hello-world

# %%
print(8)
# Out:
# 8

# %%
print(2.78)
# Out:
# 2.78

# %%
print(True)
print(False)
# Out:
# True
# False

# %%
print(7+8j)
# Out:
# (7+8j)

# %%
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
print({'name':'M.d Adnan','gender':'male','weight':'100kg'})
# Out:
# {'name': 'M.d Adnan', 'gender': 'male', 'weight': '100kg'}

# %%
type(8)
# Out:
# int

# %%
type([1,2,3])
# Out:
# list

# %%
name='Adnan'
print(name)
# Out:
# Adnan

# %%
a=6
b=9
print(a+b)
# Out:
# 15

# %%
a=1
b=2
c=3
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b,c=1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c=5
print(a,b,c)
# Out:
# 5 5 5
