# %% [markdown]
# <a href="https://colab.research.google.com/github/mapzacer-11/Machine-Learning-Journey/blob/main/Day7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Common Functions in Strings

len('hello Universe')
# Out:
# 14

# %%
max('hello universe')
# Out:
# 'v'

# %%
min('hello universe')
# Out:
# ' '

# %%
sorted('hello universe')
# Out:
# [' ', 'e', 'e', 'e', 'h', 'i', 'l', 'l', 'n', 'o', 'r', 's', 'u', 'v']

# %%
# Capitalize (only work on strings)
s='hello universe'
s.capitalize()
# Out:
# 'Hello universe'

# %%
s.title()
# Out:
# 'Hello Universe'

# %%
s.upper()
# Out:
# 'HELLO UNIVERSE'

# %%
'HELLO UNIVERSE'.lower()
# Out:
# 'hello universe'

# %%
'HeLLO WoRlD'.swapcase()
# Out:
# 'hEllo wOrLd'

# %%
#Count/Find/Index

'My name is addu'.count('a')
# Out:
# 2

# %%
'My name is addu'.find('is')
# Out:
# 8

# %%
'My name is addu'.index('x')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4096615769.py in <cell line: 0>()
# ----> 1 'My name is addu'.index('x')
#
# ValueError: substring not found

# %%
#endswith/start with

'My name is addu'.endswith('du')
# Out:
# True

# %%
'My name is addu'.startswith('My')
# Out:
# True

# %%
#format
name='addu'
gender='male'

'Hi my name is {} and I am a {}'.format(name,gender)
# Out:
# 'Hi my name is addu and I am a male'

# %%
#format
name='addu'
gender='male'

'Hi my name is {1} and I am a {0}'.format(name,gender)
# Out:
# 'Hi my name is male and I am a addu'

# %%
#isalnum/isalpha/isdigit/isidentifier

'addu780'.isalnum()
# Out:
# True

# %%
'addu*780'.isalnum()
# Out:
# False

# %%
'addu780'.isalpha()
# Out:
# False

# %%
'addu'.isalnum()
# Out:
# True

# %%
'780'.isdigit()
# Out:
# True

# %%
'addu780'.isdigit()
# Out:
# False

# %%
'first-name'.isidentifier()
# Out:
# False

# %%
#split/join (very important)

'Hi my name addu'.split()
# Out:
# ['Hi', 'my', 'name', 'addu']

# %%
'Hi my name addu'.split('a')
# Out:
# ['Hi my n', 'me ', 'ddu']

# %%
" ".join(['Hi my n', 'me ', 'ddu'])
# Out:
# 'Hi my n me  ddu'

# %%
"-".join(['Hi', 'my', 'name', 'addu'])
# Out:
# 'Hi-my-name-addu'

# %%
'Hi my name addu'.replace('addu','kaddu')
# Out:
# 'Hi my name kaddu'

# %%
'Hi my name addu'.replace('add','kaddu')
# Out:
# 'Hi my name kadduu'

# %%
#strip
'addu                                         '.strip()
# Out:
# 'addu'
