# %% [markdown]
# <a href="https://colab.research.google.com/github/mapzacer-11/Machine-Learning-Journey/blob/main/Day8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Find the length of a given string without using the len() function

s = input('enter the string')

counter = 0

for i in s:
  counter += 1

print('length of string is',counter)
# Out:
# enter the stringpythonaddu
# length of string is 10

# %%
# Extract username from a given email
# Ex , if the email is addu786@gmail.com
# Then the username should be addu786

s = input('enter the email')

pos = s.index('@')

print(s[0:pos])
# Out:
# enter the emailaddu9999@gmail.com
# addu9999

# %%
s = input('enter the email')
term = input('what would like to search for')

counter=0
for i in s:
 if i == term:
  counter += 1
print('frequency',counter)
# Out:
# enter the emailhi
# what would like to search fori
# frequency 1

# %%
s = input('enter the string')
term = input('what you like to remove')

result = ''

for i in s:
  if i !=term:
    result = result + i

print(result)
# Out:
# enter the stringanaconda
# what you like to removea
# ncond

# %%
# write a program that can check wheather a given srting is palindrome or not

s = input('enter the string')
flag= True
for i in range(0,len(s)//2):
  if s[i] != s[len(s)-i-1]:
    flag = False
    print('not palindrome')
    break
if flag:
  print('palindrome')
# Out:
# enter the stringkururu
# not palindrome
